# %% [markdown]
# <img src='https://hammondm.github.io/hltlogo1.png' style="float:right">
#
# LING 593A-011<br>
# Fall 2025<br>
# Davo Acevedo-Cardona
#
# # GUU — Firebase Upload Tool
#
# This notebook is a test sample to upload all the CSV to firebase.
#
# Sai, Lindsey and I still need to agree where the data will be uploaded (Firebase project).

# %% [markdown]
# # Imports and basic configuration

# %%
#pip install -r requirements.txt
# Out:
# Collecting firebase-admin>=6.0.0 (from -r requirements.txt (line 1))
#   Downloading firebase_admin-7.1.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: rapidfuzz>=3.0.0 in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from -r requirements.txt (line 2)) (3.14.3)
# Collecting cachecontrol>=0.14.3 (from firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading cachecontrol-0.14.4-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-api-core<3.0.0dev,>=2.25.1 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading google_api_core-2.29.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-firestore>=2.21.0 (from firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading google_cloud_firestore-2.23.0-py3-none-any.whl.metadata (10 kB)
# Collecting google-cloud-storage>=3.1.1 (from firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading google_cloud_storage-3.8.0-py3-none-any.whl.metadata (14 kB)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: httpx==0.28.1 in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from httpx[http2]==0.28.1->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: anyio in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: certifi in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: h2<5,>=3 in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from httpx[http2]==0.28.1->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (4.3.0)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading protobuf-6.33.4-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading proto_plus-1.27.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3.0.0,>=2.14.1 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading google_auth-2.47.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (2.32.5)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading grpcio-1.76.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading grpcio_status-1.76.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: h11>=0.16 in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from httpcore==1.*->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (2.5.0)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading pyasn1-0.6.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting msgpack<2.0.0,>=0.5.2 (from cachecontrol>=0.14.3->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading msgpack-1.1.2-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Collecting google-cloud-core<3.0.0,>=1.4.1 (from google-cloud-firestore>=2.21.0->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage>=3.1.1->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage>=3.1.1->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading google_crc32c-1.8.0-cp312-cp312-win_amd64.whl.metadata (1.8 kB)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.10.1->firebase-admin>=6.0.0->-r requirements.txt (line 1))
#   Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\ateni\desktop\u of a\enviroments\jupyter_env\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin>=6.0.0->-r requirements.txt (line 1)) (2.23)
# Downloading firebase_admin-7.1.0-py3-none-any.whl (137 kB)
# Downloading google_api_core-2.29.0-py3-none-any.whl (173 kB)
# Downloading google_auth-2.47.0-py3-none-any.whl (234 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading grpcio-1.76.0-cp312-cp312-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -------- ------------------------------- 1.0/4.7 MB 6.3 MB/s eta 0:00:01
#    -------------------- ------------------- 2.4/4.7 MB 5.8 MB/s eta 0:00:01
#    ------------------------------- -------- 3.7/4.7 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 5.8 MB/s  0:00:00
# Downloading grpcio_status-1.76.0-py3-none-any.whl (14 kB)
# Downloading proto_plus-1.27.0-py3-none-any.whl (50 kB)
# Downloading protobuf-6.33.4-cp310-abi3-win_amd64.whl (436 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading cachecontrol-0.14.4-py3-none-any.whl (22 kB)
# Downloading msgpack-1.1.2-cp312-cp312-win_amd64.whl (72 kB)
# Downloading google_cloud_firestore-2.23.0-py3-none-any.whl (411 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading google_cloud_storage-3.8.0-py3-none-any.whl (312 kB)
# Downloading google_crc32c-1.8.0-cp312-cp312-win_amd64.whl (34 kB)
# Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Downloading pyasn1-0.6.2-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ----------- ---------------------------- 1.0/3.5 MB 6.3 MB/s eta 0:00:01
#    -------------------------- ------------- 2.4/3.5 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 5.8 MB/s  0:00:00
# Installing collected packages: pyjwt, pyasn1, protobuf, msgpack, grpcio, google-crc32c, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, google-resumable-media, cryptography, cachecontrol, grpcio-status, google-auth, google-api-core, google-cloud-core, google-cloud-storage, google-cloud-firestore, firebase-admin
#
#    -- -------------------------------------  1/20 [pyasn1]
#    ---- -----------------------------------  2/20 [protobuf]
#    ------ ---------------------------------  3/20 [msgpack]
#    -------- -------------------------------  4/20 [grpcio]
#    ---------- -----------------------------  5/20 [google-crc32c]
#    -------------- -------------------------  7/20 [pyasn1-modules]
#    -------------- -------------------------  7/20 [pyasn1-modules]
#    -------------- -------------------------  7/20 [pyasn1-modules]
#    ---------------- -----------------------  8/20 [proto-plus]
#    ------------------ ---------------------  9/20 [googleapis-common-protos]
#    ------------------ ---------------------  9/20 [googleapis-common-protos]
#    -------------------- ------------------- 10/20 [google-resumable-media]
#    ---------------------- ----------------- 11/20 [cryptography]
#    ---------------------- ----------------- 11/20 [cryptography]
#    ---------------------- ----------------- 11/20 [cryptography]
#    ---------------------------- ----------- 14/20 [google-auth]
#    ---------------------------- ----------- 14/20 [google-auth]
#    ------------------------------ --------- 15/20 [google-api-core]
#    -------------------------------- ------- 16/20 [google-cloud-core]
#    ---------------------------------- ----- 17/20 [google-cloud-storage]
#    ---------------------------------- ----- 17/20 [google-cloud-storage]
#    ------------------------------------ --- 18/20 [google-cloud-firestore]
#    ------------------------------------ --- 18/20 [google-cloud-firestore]
#    ------------------------------------ --- 18/20 [google-cloud-firestore]
#    -------------------------------------- - 19/20 [firebase-admin]
#    ---------------------------------------- 20/20 [firebase-admin]
#
# Successfully installed cachecontrol-0.14.4 cryptography-46.0.3 firebase-admin-7.1.0 google-api-core-2.29.0 google-auth-2.47.0 google-cloud-core-2.5.0 google-cloud-firestore-2.23.0 google-cloud-storage-3.8.0 google-crc32c-1.8.0 google-resumable-media-2.8.0 googleapis-common-protos-1.72.0 grpcio-1.76.0 grpcio-status-1.76.0 msgpack-1.1.2 proto-plus-1.27.0 protobuf-6.33.4 pyasn1-0.6.2 pyasn1-modules-0.4.2 pyjwt-2.10.1 rsa-4.9.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # First Run

# %%
# !python uploader.py \
  --contacts-csv company_contacts_full.csv \
  --subsidiary-csv company_subsidiary.csv \
  --firebase-credentials ./firebase-credentials.json \
  --firebase-project guu-task-5 \
  --dry-run
# Out:
# Initializing Firebase...
# Loading brands from Firebase...
# Loaded 0 brands
# Found existing social keys: []
# Loading brands from Firebase...
# Loaded 0 brands
# Found existing social keys: []
#
# Loading contacts from: company_contacts_full.csv
# Loaded 4631 contacts
#
# Loading subsidiaries from: company_subsidiary.csv
# Filtered 328 extraction errors
# Excluded 98 incomplete subsidiary entries
# Loaded 74202 subsidiary rows
#
# ============================================================
# Processing Contacts
# ============================================================
#
# Contacts Summary:
#   Processed: 0
#   Auto-accepted: 0
#   Manual review: 0
#   Rejected: 0
#
# ============================================================
# Processing Subsidiaries
# ============================================================
#
# Subsidiaries Summary:
#   Processed: 0
#   Auto-accepted: 0
#   Manual review: 0
#   Rejected: 0
#
# Saved 0 items to manual review file: manual_review.json
# Saved 0 unmatched companies to: unmatched_companies.json
#
# ============================================================
# UPLOAD SUMMARY
# ============================================================
# Contacts:
#   Processed: 0
#   Auto-accepted: 0
#   Manual review: 0
#   Rejected: 0
#
# Subsidiaries:
#   Processed: 0
#   Auto-accepted: 0
#   Manual review: 0
#   Rejected: 0
#
# Errors: 0
# Manual review items: 0
# Unmatched companies: 0
#
# DRY RUN MODE - No data was written to Firebase

# %% [markdown]
# # Upload 1 company

# %%
# !python uploader.py \
  --contacts-csv company_contacts_full.csv \
  --subsidiary-csv company_subsidiary.csv \
  --firebase-credentials ./firebase-credentials.json \
  --firebase-project guu-task-5 \
  --single-company "3M Co" \
  --dry-run
# Out:
# Initializing Firebase...
# Loading brands from Firebase...
# Loaded 1 brands
# Found existing social keys: []
#
# Loading contacts from: company_contacts_full.csv
# Loaded 4631 contacts
#
# Loading subsidiaries from: company_subsidiary.csv
# Filtered 328 extraction errors
# Excluded 98 incomplete subsidiary entries
# Loaded 74202 subsidiary rows
#
# ============================================================
# Processing Contacts
# ============================================================
#
# Contacts Summary:
#   Processed: 0
#   Auto-accepted: 0
#   Manual review: 0
#   Rejected: 0
#
# ============================================================
# Processing Subsidiaries
# ============================================================
#
# Subsidiaries Summary:
#   Processed: 0
#   Auto-accepted: 0
#   Manual review: 0
#   Rejected: 0
#
# Saved 0 items to manual review file: manual_review.json
# Saved 0 unmatched companies to: unmatched_companies.json
#
# ============================================================
# UPLOAD SUMMARY
# ============================================================
# Contacts:
#   Processed: 0
#   Auto-accepted: 0
#   Manual review: 0
#   Rejected: 0
#
# Subsidiaries:
#   Processed: 0
#   Auto-accepted: 0
#   Manual review: 0
#   Rejected: 0
#
# Errors: 0
# Manual review items: 0
# Unmatched companies: 0
#
# DRY RUN MODE - No data was written to Firebase
